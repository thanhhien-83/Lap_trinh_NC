# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'python-docx', '-q'])
# Out:
# 0

# %%
exec(open(r'e:/Hoc_tap/BTL_Laptrinhnangcao/create_word_report.py', encoding='utf-8').read())
# Out:
# ✓ Đã tạo file báo cáo Word thành công!
#   → e:\Hoc_tap\BTL_Laptrinhnangcao\BaoCao_BTL_LapTrinhNangCao.docx
#   → Mở file bằng Microsoft Word để xem kết quả.
